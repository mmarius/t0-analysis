# %%
import sys
sys.path.insert(1, '/t0-analysis/CKA-similarity')

import numpy as np
from CKA import CKA

import matplotlib
import matplotlib.pyplot as plt

from utils import load_hidden_representations_from_hdf5, read_templates_from_file

# %%
# params
log_dir = "/logfiles"
model = "google-t5-xxl-lm-adapt"
module = "decoder"
task = "rte"

# %%
# assertions
assert model == "google-t5-xxl-lm-adapt"
assert module == "decoder"
assert task == "rte"

# %% [markdown]
# ## Prompts

# %%
df = read_templates_from_file(f"/t0-analysis/prompts/{task}/all.csv")
# df = read_templates_from_file(f"/t0-analysis/prompts/{task}/fixed_prompt.csv")
# df = read_templates_from_file(f"/t0-analysis/prompts/{task}/fixed_target_yes_no.csv")
display(df)
# Out:
#                                       name  \
# 0   gpt_3_yes_no_with_targets
# 1   mnli_crowdsource_with_targets
# 2   based_on_previous_passage_with_targets
# 3   infer_with_targets
# 4   follow_with_targets
# 5   imply_with_targets
# 6   guaranteed_with_targets
# 7   justified_with_targets
# 8   must_be_true_with_targets
# 9   should_assume_with_targets
# 10  gpt_3_true_false_with_targets
# 11  gpt_3_cat_dog_with_targets
# 12  gpt_3_cat_dog_with_targets_yes_no
# 13  gpt_3_yes_no_without_targets
# 14  words_appear_with_targets
# 15  similar_words_with_targets
# 16  start_with_the_with_targets
# 17  same_meaning_with_targets
# 18  paraphrase_with_targets
# 19  paraphrase_r_with_targets
# 20  summarize_with_targets
# 21  inflection_with_targets
# 22  null_pattern_with_targets
# 23  null_pattern_r_with_targets
# 24  null_pattern_without_targets
# 25  null_pattern_r_without_targets
# 26  premise_only_with_targets
# 27  premise_only_without_targets
# 28  hypothesis_only_with_targets
# 29  hypothesis_only_without_targets
# 30  sentiment_with_targets
# 31  sentiment_cat_dog_with_targets
#
#                                                                                                                           template  \
# 0   {premise} Question: {hypothesis} Yes or No?
# 1   {premise} Using only the above description and what you know about the world, is "{hypothesis}" definitely correct? Yes or No?
# 2   {premise} Based on the previous passage, is it true that "{hypothesis}"? Yes or No?
# 3   Suppose {premise} Can we infer that "{hypothesis}"? Yes or No?
# 4   Given that {premise} Does it follow that {hypothesis} Yes or No?
# 5   {premise} Question: Does this imply that "{hypothesis}"? Yes or No?
# 6   Given {premise} Is it guaranteed true that "{hypothesis}"? Yes or No?
# 7   {premise} Are we justified in saying that "{hypothesis}"? Yes or No?
# 8   Given that {premise} Therefore, it must be true that "{hypothesis}"? Yes or No?
# 9   Given {premise} Should we assume that "{hypothesis}" is true? Yes or No?
# 10  {premise} Question: {hypothesis} True or False?
# 11  {premise} Question: {hypothesis} Cat or Dog?
# 12  {premise} Question: {hypothesis} Cat or Dog?
# 13  {premise} Question: {hypothesis}?
# 14  {hypothesis} Do most of the above words appear in the following passage? "{premise}" Yes or No?
# 15  {premise} Are there lots of similar words in "{hypothesis}"? Yes or No?
# 16  {premise} Does the paragraph start with "the"? {hypothesis} Yes or No?
# 17  {premise} Does that have the same meaning as "{hypothesis}"? Yes or No?
# 18  {premise} Can that be paraphrased as: {hypothesis}? Yes or No?
# 19  {hypothesis} Can that be paraphrased as: {premise}? Yes or No?
# 20  {premise} Can that be summarized as "{hypothesis}"? Yes or No?
# 21  {premise} Inflections are annoying and thank god that Middle English got rid of most of them. {hypothesis}? Yes or No?
# 22  {premise} {hypothesis}? Yes or No?
# 23  {hypothesis} {premise}? Yes or No?
# 24  {premise} {hypothesis}?
# 25  {hypothesis} {premise}?
# 26  {premise}? Yes or No?
# 27  {premise}?
# 28  {hypothesis}? Yes or No?
# 29  {hypothesis}?
# 30  {premise} {hypothesis} The sentiment of the previous text is positive? Yes or No?
# 31  {premise} {hypothesis} The sentiment of the previous text is positive? Cat or Dog?
#
#        category  includes_targets               targets  target_ids  shuffle
# 0   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 1   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 2   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 3   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 4   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 5   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 6   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 7   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 8   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 9   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 10  instructive  True              ▁True, ▁Fal           0, 1        False
# 11  instructive  True              ▁Cat, ▁Dog            0, 1        False
# 12  instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 13  instructive  False             ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 14  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 15  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 16  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 17  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 18  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 19  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 20  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 21  irrelevant   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 22  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 23  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 24  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 25  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 26  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 27  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 28  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 29  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 30  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 31  misleading   True              ▁Cat, ▁Dog            0, 1        False

# %% [markdown]
# ## Comput CKA

# %%
use_pattern = [
    "gpt_3_yes_no_with_targets",
    "mnli_crowdsource_with_targets",
    "based_on_previous_passage_with_targets",
    "infer_with_targets",
    "follow_with_targets",
    "imply_with_targets",
    "guaranteed_with_targets",
    "justified_with_targets",
    "must_be_true_with_targets",
    "should_assume_with_targets",
    "gpt_3_true_false_with_targets",
    "gpt_3_cat_dog_with_targets",
    "gpt_3_cat_dog_with_targets_yes_no",
    "gpt_3_yes_no_without_targets",
    "words_appear_with_targets",
    "similar_words_with_targets",
    "start_with_the_with_targets",
    "same_meaning_with_targets",
    "paraphrase_with_targets",
    "paraphrase_r_with_targets",
    "summarize_with_targets",
    "inflection_with_targets",
    "null_pattern_with_targets",
    "null_pattern_r_with_targets",
    "null_pattern_without_targets",
    "null_pattern_r_without_targets",
    "premise_only_with_targets",
    "premise_only_without_targets",
    "hypothesis_only_with_targets",
    "hypothesis_only_without_targets",
    "sentiment_with_targets",
    "sentiment_cat_dog_with_targets"
]

# %%
representations = {}

# For decoder representations we need to additionally specify the generated token
# We currently save representations for t=0 and t=1
# for t in range(2):
for t in range(1):
    if t not in representations:
            representations[t] = {}

    # for layer in range(0, 1):
    # for layer in range(0, 5):
    for layer in range(0, 25):
    # for layer in range(24, 25):
        
        file_names, prompt_names = [], []

        layer_key = f"{module}-{layer}"
        if layer_key not in representations[t]:
            representations[t][layer_key] = {}
        
        for _, row in df.iterrows():
            if row['name'] in use_pattern:
                file_name = f"{task}/{model}/{module}/{row['name']}/hidden_represenations_t{t}_layer{layer}_avg.hdf5"
                file_names.append(file_name)
                prompt_names.append(row['name'])
                if file_name not in representations[t][layer_key]:
                    # load hidden representations from hdf5 file
                    representations[t][layer_key][file_name] = load_hidden_representations_from_hdf5(os.path.join(log_dir, file_name), silent=True)

# %%
representations[0]["decoder-0"].keys()
# Out:
# dict_keys(['rte/google-t5-xxl-lm-adapt/decoder/gpt_3_yes_no_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/mnli_crowdsource_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/based_on_previous_passage_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/infer_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/follow_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/imply_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/guaranteed_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/justified_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/must_be_true_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/should_assume_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/gpt_3_true_false_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/gpt_3_cat_dog_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/gpt_3_cat_dog_with_targets_yes_no/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/gpt_3_yes_no_without_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/words_appear_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/similar_words_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/start_with_the_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/same_meaning_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/paraphrase_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/paraphrase_r_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/summarize_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/inflection_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/null_pattern_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/null_pattern_r_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/null_pattern_without_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/null_pattern_r_without_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/premise_only_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/premise_only_without_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/hypothesis_only_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/hypothesis_only_without_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/sentiment_with_targets/hidden_represenations_t0_layer0_avg.hdf5', 'rte/google-t5-xxl-lm-adapt/decoder/sentiment_cat_dog_with_targets/hidden_represenations_t0_layer0_avg.hdf5'])

# %%
len(representations[0]["decoder-0"].keys())
# Out:
# 32

# %%
# Compute pairwise CKA for every layer
np_cka = CKA()

cka_scores_layers = {}

# for t in range(2):
for t in range(1):
    if t not in cka_scores_layers:
        cka_scores_layers[t] = {}

    for layer in list(representations[t].keys())[:]:
        cka_scores = []
        for pattern1 in representations[t][layer].keys():
            cka_scores_pattern1 = []
            for pattern2 in representations[t][layer].keys():
                cka_score = np_cka.linear_CKA(representations[t][layer][pattern1], representations[t][layer][pattern2])
                cka_scores_pattern1.append(cka_score)
            cka_scores.append(cka_scores_pattern1)
        cka_scores = np.asarray(cka_scores)
        cka_scores_layers[t][layer] = cka_scores
        # print(cka_scores.shape)

# %%
for token_key in cka_scores_layers.keys():
    for layer_key in cka_scores_layers[token_key].keys():
        values = cka_scores_layers[token_key][layer_key]
        layer = layer_key.split('-')[-1]

        fig, axes = plt.subplots(1, 1, figsize=(5.5,4), dpi=100)

        im = axes.imshow(values, cmap='inferno', vmax=1.0)
        # Create colorbar
        cbar = axes.figure.colorbar(im, ax=axes)
        cbar.ax.set_ylabel("", rotation=-90, va="bottom")

        axes.set_xlabel("template", fontsize=8)
        axes.set_xticks(np.arange(len(values)))
        axes.set_ylabel("template", fontsize=8)
        axes.set_yticks(np.arange(len(values)))

        axes.set_title(f"Pairwise CKA ({model}; {module}; {task}; token={token_key}; layer={layer})", fontsize=8)

        plt.tight_layout()
        plt.show()
        plt.close();

# %%
# for t in range(2):
for t in range(1):
    plt.figure(figsize=(8, 8), dpi=120)

    for l, layer_key in enumerate(cka_scores_layers[t].keys()):
        values = cka_scores_layers[t][layer_key]
        layer = layer_key.split('-')[-1]

        plt.subplot(5, 5, l+1)
        axes = plt.gca()
        axes.get_xaxis().set_visible(False)
        axes.get_yaxis().set_visible(False)
        im = axes.imshow(values, cmap='inferno', vmin=0.0, vmax=1.0)
        # Create colorbar
        # cbar = axes.figure.colorbar(im, ax=axes)
        # cbar.ax.set_ylabel("", rotation=-90, va="bottom")

        axes.set_xlabel("template", fontsize=8)
        axes.set_xticks(np.arange(len(values)))
        axes.set_ylabel("template", fontsize=8)
        axes.set_yticks(np.arange(len(values)))

        # axes.set_title(f"Pairwise CKA ({model}; {module}; {task}; layer={layer})", fontsize=8)
        axes.set_title(f"layer={layer}", fontsize=8)

    # add colorbar
    fig = plt.gcf()
    fig.subplots_adjust(right=0.8)
    cbar_ax = fig.add_axes([0.99, 0.05, 0.01, 0.85])
    fig.colorbar(im, cax=cbar_ax)

    plt.suptitle(f"Pairwise CKA ({model}; {module}; {task}: token={t})")
    plt.tight_layout()
    plt.show()
    plt.close();
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
df
# Out:
#                                       name  \
# 0   gpt_3_yes_no_with_targets
# 1   mnli_crowdsource_with_targets
# 2   based_on_previous_passage_with_targets
# 3   infer_with_targets
# 4   follow_with_targets
# 5   imply_with_targets
# 6   guaranteed_with_targets
# 7   justified_with_targets
# 8   must_be_true_with_targets
# 9   should_assume_with_targets
# 10  gpt_3_true_false_with_targets
# 11  gpt_3_cat_dog_with_targets
# 12  gpt_3_cat_dog_with_targets_yes_no
# 13  gpt_3_yes_no_without_targets
# 14  words_appear_with_targets
# 15  similar_words_with_targets
# 16  start_with_the_with_targets
# 17  same_meaning_with_targets
# 18  paraphrase_with_targets
# 19  paraphrase_r_with_targets
# 20  summarize_with_targets
# 21  inflection_with_targets
# 22  null_pattern_with_targets
# 23  null_pattern_r_with_targets
# 24  null_pattern_without_targets
# 25  null_pattern_r_without_targets
# 26  premise_only_with_targets
# 27  premise_only_without_targets
# 28  hypothesis_only_with_targets
# 29  hypothesis_only_without_targets
# 30  sentiment_with_targets
# 31  sentiment_cat_dog_with_targets
#
#                                                                                                                           template  \
# 0   {premise} Question: {hypothesis} Yes or No?
# 1   {premise} Using only the above description and what you know about the world, is "{hypothesis}" definitely correct? Yes or No?
# 2   {premise} Based on the previous passage, is it true that "{hypothesis}"? Yes or No?
# 3   Suppose {premise} Can we infer that "{hypothesis}"? Yes or No?
# 4   Given that {premise} Does it follow that {hypothesis} Yes or No?
# 5   {premise} Question: Does this imply that "{hypothesis}"? Yes or No?
# 6   Given {premise} Is it guaranteed true that "{hypothesis}"? Yes or No?
# 7   {premise} Are we justified in saying that "{hypothesis}"? Yes or No?
# 8   Given that {premise} Therefore, it must be true that "{hypothesis}"? Yes or No?
# 9   Given {premise} Should we assume that "{hypothesis}" is true? Yes or No?
# 10  {premise} Question: {hypothesis} True or False?
# 11  {premise} Question: {hypothesis} Cat or Dog?
# 12  {premise} Question: {hypothesis} Cat or Dog?
# 13  {premise} Question: {hypothesis}?
# 14  {hypothesis} Do most of the above words appear in the following passage? "{premise}" Yes or No?
# 15  {premise} Are there lots of similar words in "{hypothesis}"? Yes or No?
# 16  {premise} Does the paragraph start with "the"? {hypothesis} Yes or No?
# 17  {premise} Does that have the same meaning as "{hypothesis}"? Yes or No?
# 18  {premise} Can that be paraphrased as: {hypothesis}? Yes or No?
# 19  {hypothesis} Can that be paraphrased as: {premise}? Yes or No?
# 20  {premise} Can that be summarized as "{hypothesis}"? Yes or No?
# 21  {premise} Inflections are annoying and thank god that Middle English got rid of most of them. {hypothesis}? Yes or No?
# 22  {premise} {hypothesis}? Yes or No?
# 23  {hypothesis} {premise}? Yes or No?
# 24  {premise} {hypothesis}?
# 25  {hypothesis} {premise}?
# 26  {premise}? Yes or No?
# 27  {premise}?
# 28  {hypothesis}? Yes or No?
# 29  {hypothesis}?
# 30  {premise} {hypothesis} The sentiment of the previous text is positive? Yes or No?
# 31  {premise} {hypothesis} The sentiment of the previous text is positive? Cat or Dog?
#
#        category  includes_targets               targets  target_ids  shuffle
# 0   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 1   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 2   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 3   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 4   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 5   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 6   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 7   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 8   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 9   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 10  instructive  True              ▁True, ▁Fal           0, 1        False
# 11  instructive  True              ▁Cat, ▁Dog            0, 1        False
# 12  instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 13  instructive  False             ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 14  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 15  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 16  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 17  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 18  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 19  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 20  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 21  irrelevant   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 22  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 23  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 24  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 25  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 26  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 27  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 28  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 29  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 30  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 31  misleading   True              ▁Cat, ▁Dog            0, 1        False

# %%
# pattern1 = 0

# # for t in range(2):
# for t in range(1):

#     fig, axes = plt.subplots(1, 1, figsize=(5.5, 4), dpi=100)

#     # cmap = matplotlib.cm.get_cmap('tab10')
#     cmap = matplotlib.cm.get_cmap('tab20')
#     colors = cmap.colors

#     for idx, pattern2 in enumerate(range(len(df))[:]):
#         if pattern2 == pattern1:
#             continue
#         pattern_sim = []

#         layers = []
#         for layer in list(cka_scores_layers[t].keys())[-5:]:
#             layers.append(layer.split('-')[-1])
#             cka_score = cka_scores_layers[t][layer][pattern1, pattern2]
#             pattern_sim.append(cka_score)
        
#         axes.plot(pattern_sim, linewidth=2.0, alpha=0.6, color=colors[idx], label=f"{df.iloc[pattern2]['name']}")

#     axes.set_ylim(-0.05, 1.05)
#     axes.set_xticks(np.arange(len(pattern_sim)))
#     axes.set_xticklabels(layers)
#     axes.set_xlabel("layer index")
#     axes.set_ylabel("CKA score")

#     axes.set_title(f"pattern={df.iloc[pattern1]['name']} ({model}; {module}; {task}; layer={layer.split('-')[-1]})", fontsize=8)

#     axes.legend(loc='best', fontsize=8)
#     # Put a legend to the right of the current axis
#     # axes.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fancybox=True, shadow=False, fontsize=8)

#     plt.tight_layout();
