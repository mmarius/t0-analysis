# %%
import sys
import numpy as np
import pandas as pd 
pd.set_option('display.max_colwidth', -1)

from transformers import AutoTokenizer

from utils import load_hidden_representations_from_hdf5, read_templates_from_file
from task_helpers import TASK_LABELS

# %%
def get_target_scores(model_name_or_path, template_name, targets):
    targets = [t.strip() for t in targets[0].split(',')]
    tokenizer = AutoTokenizer.from_pretrained(
        model_name_or_path, cache_dir="/pre-trained-transformers"
    )
    scores = np.load(f"/logfiles/{task}/{model}/{module}/{template_name}/scores_t0.npy")
    target_ids = [tokenizer._convert_token_to_id_with_added_voc(t) for t in targets]
    # print(targets, target_ids)
    target_scores, argmax_scores, max_scores = [], [], []
    for sid in range(len(scores)):
        values = [scores[sid][tid] for tid in target_ids]
        target_scores.append(values)
        argmax_scores.append(np.argmax(values))
        max_scores.append(np.max(values))
    return targets, target_ids, target_scores, argmax_scores, max_scores

# %%
# params
log_dir = "/logfiles"
module = "encoder"
task = "rte"

# %%
MODEL_NAMES = {
    "bigscience-T0_3B": "bigscience/T0_3B", 
    "bigscience-T0": "bigscience/T0", 
    "google-t5-xl-lm-adapt": "google/t5-xl-lm-adapt",
    "google-t5-xxl-lm-adapt": "google/t5-xxl-lm-adapt",
}

# %%
df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/all.csv")
# df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/fixed_prompt.csv")
# df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/fixed_target_yes_no.csv")
# df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/irrelevant.csv")
# df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/misleading.csv")
# df_prompts = read_templates_from_file(f"/t0-analysis/prompts/{task}/controls.csv")
display(df_prompts)
# Out:
#                                       name  \
# 0   gpt_3_yes_no_with_targets
# 1   mnli_crowdsource_with_targets
# 2   based_on_previous_passage_with_targets
# 3   infer_with_targets
# 4   follow_with_targets
# 5   imply_with_targets
# 6   guaranteed_with_targets
# 7   justified_with_targets
# 8   must_be_true_with_targets
# 9   should_assume_with_targets
# 10  gpt_3_true_false_with_targets
# 11  gpt_3_cat_dog_with_targets
# 12  gpt_3_cat_dog_with_targets_yes_no
# 13  gpt_3_yes_no_without_targets
# 14  words_appear_with_targets
# 15  similar_words_with_targets
# 16  start_with_the_with_targets
# 17  same_meaning_with_targets
# 18  paraphrase_with_targets
# 19  paraphrase_r_with_targets
# 20  summarize_with_targets
# 21  inflection_with_targets
# 22  null_pattern_with_targets
# 23  null_pattern_r_with_targets
# 24  null_pattern_without_targets
# 25  null_pattern_r_without_targets
# 26  premise_only_with_targets
# 27  premise_only_without_targets
# 28  hypothesis_only_with_targets
# 29  hypothesis_only_without_targets
# 30  sentiment_with_targets
# 31  sentiment_cat_dog_with_targets
#
#                                                                                                                           template  \
# 0   {premise} Question: {hypothesis} Yes or No?
# 1   {premise} Using only the above description and what you know about the world, is "{hypothesis}" definitely correct? Yes or No?
# 2   {premise} Based on the previous passage, is it true that "{hypothesis}"? Yes or No?
# 3   Suppose {premise} Can we infer that "{hypothesis}"? Yes or No?
# 4   Given that {premise} Does it follow that {hypothesis} Yes or No?
# 5   {premise} Question: Does this imply that "{hypothesis}"? Yes or No?
# 6   Given {premise} Is it guaranteed true that "{hypothesis}"? Yes or No?
# 7   {premise} Are we justified in saying that "{hypothesis}"? Yes or No?
# 8   Given that {premise} Therefore, it must be true that "{hypothesis}"? Yes or No?
# 9   Given {premise} Should we assume that "{hypothesis}" is true? Yes or No?
# 10  {premise} Question: {hypothesis} True or False?
# 11  {premise} Question: {hypothesis} Cat or Dog?
# 12  {premise} Question: {hypothesis} Cat or Dog?
# 13  {premise} Question: {hypothesis}?
# 14  {hypothesis} Do most of the above words appear in the following passage? "{premise}" Yes or No?
# 15  {premise} Are there lots of similar words in "{hypothesis}"? Yes or No?
# 16  {premise} Does the paragraph start with "the"? {hypothesis} Yes or No?
# 17  {premise} Does that have the same meaning as "{hypothesis}"? Yes or No?
# 18  {premise} Can that be paraphrased as: {hypothesis}? Yes or No?
# 19  {hypothesis} Can that be paraphrased as: {premise}? Yes or No?
# 20  {premise} Can that be summarized as "{hypothesis}"? Yes or No?
# 21  {premise} Inflections are annoying and thank god that Middle English got rid of most of them. {hypothesis}? Yes or No?
# 22  {premise} {hypothesis}? Yes or No?
# 23  {hypothesis} {premise}? Yes or No?
# 24  {premise} {hypothesis}?
# 25  {hypothesis} {premise}?
# 26  {premise}? Yes or No?
# 27  {premise}?
# 28  {hypothesis}? Yes or No?
# 29  {hypothesis}?
# 30  {premise} {hypothesis} The sentiment of the previous text is positive? Yes or No?
# 31  {premise} {hypothesis} The sentiment of the previous text is positive? Cat or Dog?
#
#        category  includes_targets               targets  target_ids  shuffle
# 0   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 1   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 2   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 3   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 4   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 5   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 6   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 7   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 8   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 9   instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 10  instructive  True              ▁True, ▁Fal           0, 1        False
# 11  instructive  True              ▁Cat, ▁Dog            0, 1        False
# 12  instructive  True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 13  instructive  False             ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 14  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 15  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 16  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 17  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 18  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 19  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 20  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 21  irrelevant   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 22  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 23  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 24  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 25  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 26  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 27  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 28  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 29  control      True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 30  misleading   True              ▁Yes, ▁No, ▁yes, ▁no  0, 1, 0, 1  False
# 31  misleading   True              ▁Cat, ▁Dog            0, 1        False

# %%
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/all_.csv", sep=";", index=False)
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/fixed_prompt_.csv", sep=";", index=False)
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/fixed_target_yes_no_.csv", sep=";", index=False)
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/irrelevant_.csv", sep=";", index=False)
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/misleading_.csv", sep=";", index=False)
# df_prompts.to_csv(f"/t0-analysis/prompts/{task}/controls_.csv", sep=";", index=False)

# %%
use_pattern = [
    "gpt_3_yes_no_with_targets",
    "mnli_crowdsource_with_targets",
    "based_on_previous_passage_with_targets",
    "infer_with_targets",
    "follow_with_targets",
    "imply_with_targets",
    "guaranteed_with_targets",
    "justified_with_targets",
    "must_be_true_with_targets",
    "should_assume_with_targets",
    "gpt_3_true_false_with_targets",
    "gpt_3_cat_dog_with_targets",
    "gpt_3_cat_dog_with_targets_yes_no",
    "gpt_3_yes_no_without_targets",
    "words_appear_with_targets",
    "similar_words_with_targets",
    "start_with_the_with_targets",
    "same_meaning_with_targets",
    "paraphrase_with_targets",
    "paraphrase_r_with_targets",
    "summarize_with_targets",
    "inflection_with_targets",
    "null_pattern_with_targets",
    "null_pattern_r_with_targets",
    "null_pattern_without_targets",
    "null_pattern_r_without_targets",
    "premise_only_with_targets",
    "premise_only_without_targets",
    "hypothesis_only_with_targets",
    "hypothesis_only_without_targets",
    "sentiment_with_targets",
    "sentiment_cat_dog_with_targets"
]

# %% [markdown]
# ## Compute task performance

# %%
models_inputs, models_performance = {}, {}


for model in ["bigscience-T0_3B", "bigscience-T0", "google-t5-xl-lm-adapt", "google-t5-xxl-lm-adapt"]:
# for model in ["bigscience-T0_3B"]:
# for model in ["bigscience-T0_3B", "google-t5-xl-lm-adapt"]:
# for model in ["bigscience-T0"]:
# for model in ["bigscience-T0", "google-t5-xxl-lm-adapt"]:
    # load prompted inputs and labels
    print(model)
    df_inputs = {}

    print('collecting scores...')
    for _, row in df_prompts.iterrows():
        prompt = row['name']
        if prompt in use_pattern:
            # print(prompt)
            df_inputs[prompt] = pd.read_csv(f"/logfiles/{task}/{model}/{module}/{prompt}/prompted_samples.csv", sep='\t', index_col=0)
            
            # get scores
            targets, target_ids, target_scores, argmax_scores, max_scores = get_target_scores(MODEL_NAMES[model], prompt, df_prompts[df_prompts["name"]== prompt]["targets"].values)
            # print(targets, target_ids, argmax_scores)
            
            targets = [targets] * len(df_inputs[prompt])
            argmax_prediction = [TASK_LABELS[task][idx % 2] for idx in argmax_scores] # % number of classes

            df_inputs[prompt]["targets"] = targets
            df_inputs[prompt]["target_ids"] = [target_ids] * len(df_inputs[prompt])
            df_inputs[prompt]["scores"] = target_scores
            df_inputs[prompt]["max score"] = max_scores
            df_inputs[prompt]["argmax score"] = argmax_scores
            df_inputs[prompt]["argmax score prediction"] = argmax_prediction
    
    models_inputs[model] = df_inputs
    
    print('computing accuracy...')
    # compute performance for each prompt
    performances = {"task em performance": [], "task score performance": []}
    for template in df_inputs.keys():
        # print(template)
        df = df_inputs[template]
        predictions = [str(v) for v in df["prediction"].values]
        score_predictions = [str(v) for v in df["argmax score prediction"].values]
        labels = [str(v) for v in df["label"].values]
        correct_predictions = [1 if p == l else 0 for (p,l) in zip(predictions, labels)]
        correct_score_predictions = [1 if p == l else 0 for (p,l) in zip(score_predictions, labels)]
        performances["task em performance"].append(np.sum(correct_predictions) / len(df))
        performances["task score performance"].append(np.sum(correct_score_predictions) / len(df))

        
    performances_df = pd.DataFrame(performances, index=df_inputs.keys())
    models_performance[model] = performances_df
    print("\n")
# Out:
# bigscience-T0_3B
# collecting scores...
# Downloading:   0%|          | 0.00/632 [00:00<?, ?B/s]
# computing accuracy...
#
#
# bigscience-T0
# collecting scores...
# Downloading:   0%|          | 0.00/633 [00:00<?, ?B/s]
# computing accuracy...
#
#
# google-t5-xl-lm-adapt
# collecting scores...
# computing accuracy...
#
#
# google-t5-xxl-lm-adapt
# collecting scores...
# computing accuracy...

# %%
models_performance.keys()
# Out:
# dict_keys(['bigscience-T0_3B', 'bigscience-T0', 'google-t5-xl-lm-adapt', 'google-t5-xxl-lm-adapt'])

# %%
for model in models_performance:
    print(model)
    display(models_performance[model])
    # print(model, "(sorted by task score performance)")
    # display(models[model].sort_values("task score performance", ascending=False))
    print("\n")
# Out:
# bigscience-T0_3B
#                                         task em performance  \
# gpt_3_yes_no_with_targets               0.566787
# mnli_crowdsource_with_targets           0.606498
# based_on_previous_passage_with_targets  0.693141
# infer_with_targets                      0.599278
# follow_with_targets                     0.592058
# imply_with_targets                      0.574007
# guaranteed_with_targets                 0.635379
# justified_with_targets                  0.606498
# must_be_true_with_targets               0.703971
# should_assume_with_targets              0.646209
# gpt_3_true_false_with_targets           0.624549
# gpt_3_cat_dog_with_targets              0.440433
# gpt_3_cat_dog_with_targets_yes_no       0.007220
# gpt_3_yes_no_without_targets            0.046931
# words_appear_with_targets               0.523466
# similar_words_with_targets              0.574007
# start_with_the_with_targets             0.570397
# same_meaning_with_targets               0.617329
# paraphrase_with_targets                 0.660650
# paraphrase_r_with_targets               0.527076
# summarize_with_targets                  0.620939
# inflection_with_targets                 0.581227
# null_pattern_with_targets               0.541516
# null_pattern_r_with_targets             0.487365
# null_pattern_without_targets            0.007220
# null_pattern_r_without_targets          0.003610
# premise_only_with_targets               0.458484
# premise_only_without_targets            0.003610
# hypothesis_only_with_targets            0.472924
# hypothesis_only_without_targets         0.003610
# sentiment_with_targets                  0.400722
# sentiment_cat_dog_with_targets          0.003610
#
#                                         task score performance
# gpt_3_yes_no_with_targets               0.566787
# mnli_crowdsource_with_targets           0.606498
# based_on_previous_passage_with_targets  0.693141
# infer_with_targets                      0.599278
# follow_with_targets                     0.592058
# imply_with_targets                      0.574007
# guaranteed_with_targets                 0.635379
# justified_with_targets                  0.606498
# must_be_true_with_targets               0.703971
# should_assume_with_targets              0.646209
# gpt_3_true_false_with_targets           0.624549
# gpt_3_cat_dog_with_targets              0.476534
# gpt_3_cat_dog_with_targets_yes_no       0.487365
# gpt_3_yes_no_without_targets            0.595668
# words_appear_with_targets               0.523466
# similar_words_with_targets              0.574007
# start_with_the_with_targets             0.570397
# same_meaning_with_targets               0.617329
# paraphrase_with_targets                 0.660650
# paraphrase_r_with_targets               0.534296
# summarize_with_targets                  0.620939
# inflection_with_targets                 0.588448
# null_pattern_with_targets               0.563177
# null_pattern_r_with_targets             0.505415
# null_pattern_without_targets            0.541516
# null_pattern_r_without_targets          0.501805
# premise_only_with_targets               0.472924
# premise_only_without_targets            0.480144
# hypothesis_only_with_targets            0.472924
# hypothesis_only_without_targets         0.501805
# sentiment_with_targets                  0.584838
# sentiment_cat_dog_with_targets          0.476534
# bigscience-T0
#                                         task em performance  \
# gpt_3_yes_no_with_targets               0.805054
# mnli_crowdsource_with_targets           0.841155
# based_on_previous_passage_with_targets  0.848375
# infer_with_targets                      0.819495
# follow_with_targets                     0.747292
# imply_with_targets                      0.851986
# guaranteed_with_targets                 0.819495
# justified_with_targets                  0.776173
# must_be_true_with_targets               0.833935
# should_assume_with_targets              0.837545
# gpt_3_true_false_with_targets           0.823105
# gpt_3_cat_dog_with_targets              0.472924
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# gpt_3_yes_no_without_targets            0.292419
# words_appear_with_targets               0.732852
# similar_words_with_targets              0.740072
# start_with_the_with_targets             0.743682
# same_meaning_with_targets               0.740072
# paraphrase_with_targets                 0.776173
# paraphrase_r_with_targets               0.624549
# summarize_with_targets                  0.761733
# inflection_with_targets                 0.732852
# null_pattern_with_targets               0.693141
# null_pattern_r_with_targets             0.588448
# null_pattern_without_targets            0.014440
# null_pattern_r_without_targets          0.007220
# premise_only_with_targets               0.483755
# premise_only_without_targets            0.000000
# hypothesis_only_with_targets            0.494585
# hypothesis_only_without_targets         0.000000
# sentiment_with_targets                  0.148014
# sentiment_cat_dog_with_targets          0.036101
#
#                                         task score performance
# gpt_3_yes_no_with_targets               0.805054
# mnli_crowdsource_with_targets           0.841155
# based_on_previous_passage_with_targets  0.848375
# infer_with_targets                      0.819495
# follow_with_targets                     0.747292
# imply_with_targets                      0.851986
# guaranteed_with_targets                 0.819495
# justified_with_targets                  0.776173
# must_be_true_with_targets               0.833935
# should_assume_with_targets              0.837545
# gpt_3_true_false_with_targets           0.823105
# gpt_3_cat_dog_with_targets              0.472924
# gpt_3_cat_dog_with_targets_yes_no       0.588448
# gpt_3_yes_no_without_targets            0.801444
# words_appear_with_targets               0.732852
# similar_words_with_targets              0.740072
# start_with_the_with_targets             0.743682
# same_meaning_with_targets               0.740072
# paraphrase_with_targets                 0.776173
# paraphrase_r_with_targets               0.624549
# summarize_with_targets                  0.761733
# inflection_with_targets                 0.732852
# null_pattern_with_targets               0.693141
# null_pattern_r_with_targets             0.602888
# null_pattern_without_targets            0.581227
# null_pattern_r_without_targets          0.541516
# premise_only_with_targets               0.494585
# premise_only_without_targets            0.476534
# hypothesis_only_with_targets            0.494585
# hypothesis_only_without_targets         0.480144
# sentiment_with_targets                  0.667870
# sentiment_cat_dog_with_targets          0.462094
# google-t5-xl-lm-adapt
#                                         task em performance  \
# gpt_3_yes_no_with_targets               0.000000
# mnli_crowdsource_with_targets           0.000000
# based_on_previous_passage_with_targets  0.000000
# infer_with_targets                      0.007220
# follow_with_targets                     0.151625
# imply_with_targets                      0.018051
# guaranteed_with_targets                 0.003610
# justified_with_targets                  0.148014
# must_be_true_with_targets               0.191336
# should_assume_with_targets              0.000000
# gpt_3_true_false_with_targets           0.000000
# gpt_3_cat_dog_with_targets              0.007220
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# gpt_3_yes_no_without_targets            0.000000
# words_appear_with_targets               0.000000
# similar_words_with_targets              0.000000
# start_with_the_with_targets             0.050542
# same_meaning_with_targets               0.083032
# paraphrase_with_targets                 0.108303
# paraphrase_r_with_targets               0.043321
# summarize_with_targets                  0.101083
# inflection_with_targets                 0.158845
# null_pattern_with_targets               0.231047
# null_pattern_r_with_targets             0.151625
# null_pattern_without_targets            0.000000
# null_pattern_r_without_targets          0.000000
# premise_only_with_targets               0.148014
# premise_only_without_targets            0.000000
# hypothesis_only_with_targets            0.173285
# hypothesis_only_without_targets         0.000000
# sentiment_with_targets                  0.108303
# sentiment_cat_dog_with_targets          0.079422
#
#                                         task score performance
# gpt_3_yes_no_with_targets               0.552347
# mnli_crowdsource_with_targets           0.527076
# based_on_previous_passage_with_targets  0.527076
# infer_with_targets                      0.527076
# follow_with_targets                     0.530686
# imply_with_targets                      0.527076
# guaranteed_with_targets                 0.527076
# justified_with_targets                  0.527076
# must_be_true_with_targets               0.527076
# should_assume_with_targets              0.537906
# gpt_3_true_false_with_targets           0.523466
# gpt_3_cat_dog_with_targets              0.523466
# gpt_3_cat_dog_with_targets_yes_no       0.476534
# gpt_3_yes_no_without_targets            0.548736
# words_appear_with_targets               0.527076
# similar_words_with_targets              0.527076
# start_with_the_with_targets             0.530686
# same_meaning_with_targets               0.527076
# paraphrase_with_targets                 0.527076
# paraphrase_r_with_targets               0.527076
# summarize_with_targets                  0.527076
# inflection_with_targets                 0.530686
# null_pattern_with_targets               0.537906
# null_pattern_r_with_targets             0.530686
# null_pattern_without_targets            0.480144
# null_pattern_r_without_targets          0.465704
# premise_only_with_targets               0.523466
# premise_only_without_targets            0.462094
# hypothesis_only_with_targets            0.530686
# hypothesis_only_without_targets         0.483755
# sentiment_with_targets                  0.527076
# sentiment_cat_dog_with_targets          0.527076
# google-t5-xxl-lm-adapt
#                                         task em performance  \
# gpt_3_yes_no_with_targets               0.003610
# mnli_crowdsource_with_targets           0.000000
# based_on_previous_passage_with_targets  0.010830
# infer_with_targets                      0.018051
# follow_with_targets                     0.010830
# imply_with_targets                      0.003610
# guaranteed_with_targets                 0.000000
# justified_with_targets                  0.010830
# must_be_true_with_targets               0.003610
# should_assume_with_targets              0.021661
# gpt_3_true_false_with_targets           0.000000
# gpt_3_cat_dog_with_targets              0.000000
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# gpt_3_yes_no_without_targets            0.000000
# words_appear_with_targets               0.144404
# similar_words_with_targets              0.000000
# start_with_the_with_targets             0.028881
# same_meaning_with_targets               0.003610
# paraphrase_with_targets                 0.007220
# paraphrase_r_with_targets               0.021661
# summarize_with_targets                  0.003610
# inflection_with_targets                 0.007220
# null_pattern_with_targets               0.025271
# null_pattern_r_with_targets             0.043321
# null_pattern_without_targets            0.000000
# null_pattern_r_without_targets          0.000000
# premise_only_with_targets               0.025271
# premise_only_without_targets            0.000000
# hypothesis_only_with_targets            0.003610
# hypothesis_only_without_targets         0.000000
# sentiment_with_targets                  0.007220
# sentiment_cat_dog_with_targets          0.000000
#
#                                         task score performance
# gpt_3_yes_no_with_targets               0.581227
# mnli_crowdsource_with_targets           0.523466
# based_on_previous_passage_with_targets  0.527076
# infer_with_targets                      0.527076
# follow_with_targets                     0.530686
# imply_with_targets                      0.534296
# guaranteed_with_targets                 0.530686
# justified_with_targets                  0.530686
# must_be_true_with_targets               0.530686
# should_assume_with_targets              0.530686
# gpt_3_true_false_with_targets           0.490975
# gpt_3_cat_dog_with_targets              0.494585
# gpt_3_cat_dog_with_targets_yes_no       0.552347
# gpt_3_yes_no_without_targets            0.592058
# words_appear_with_targets               0.527076
# similar_words_with_targets              0.527076
# start_with_the_with_targets             0.527076
# same_meaning_with_targets               0.530686
# paraphrase_with_targets                 0.530686
# paraphrase_r_with_targets               0.527076
# summarize_with_targets                  0.534296
# inflection_with_targets                 0.527076
# null_pattern_with_targets               0.530686
# null_pattern_r_with_targets             0.519856
# null_pattern_without_targets            0.490975
# null_pattern_r_without_targets          0.469314
# premise_only_with_targets               0.519856
# premise_only_without_targets            0.465704
# hypothesis_only_with_targets            0.530686
# hypothesis_only_without_targets         0.480144
# sentiment_with_targets                  0.527076
# sentiment_cat_dog_with_targets          0.523466

# %%
for model in models_performance:
    # print(model)
    # display(models[model])
    print(model, "(sorted by task score performance)")
    display(models_performance[model].sort_values("task score performance", ascending=False))
    print("\n")
# Out:
# bigscience-T0_3B (sorted by task score performance)
#                                         task em performance  \
# must_be_true_with_targets               0.703971
# based_on_previous_passage_with_targets  0.693141
# paraphrase_with_targets                 0.660650
# should_assume_with_targets              0.646209
# guaranteed_with_targets                 0.635379
# gpt_3_true_false_with_targets           0.624549
# summarize_with_targets                  0.620939
# same_meaning_with_targets               0.617329
# justified_with_targets                  0.606498
# mnli_crowdsource_with_targets           0.606498
# infer_with_targets                      0.599278
# gpt_3_yes_no_without_targets            0.046931
# follow_with_targets                     0.592058
# inflection_with_targets                 0.581227
# sentiment_with_targets                  0.400722
# imply_with_targets                      0.574007
# similar_words_with_targets              0.574007
# start_with_the_with_targets             0.570397
# gpt_3_yes_no_with_targets               0.566787
# null_pattern_with_targets               0.541516
# null_pattern_without_targets            0.007220
# paraphrase_r_with_targets               0.527076
# words_appear_with_targets               0.523466
# null_pattern_r_with_targets             0.487365
# null_pattern_r_without_targets          0.003610
# hypothesis_only_without_targets         0.003610
# gpt_3_cat_dog_with_targets_yes_no       0.007220
# premise_only_without_targets            0.003610
# gpt_3_cat_dog_with_targets              0.440433
# sentiment_cat_dog_with_targets          0.003610
# premise_only_with_targets               0.458484
# hypothesis_only_with_targets            0.472924
#
#                                         task score performance
# must_be_true_with_targets               0.703971
# based_on_previous_passage_with_targets  0.693141
# paraphrase_with_targets                 0.660650
# should_assume_with_targets              0.646209
# guaranteed_with_targets                 0.635379
# gpt_3_true_false_with_targets           0.624549
# summarize_with_targets                  0.620939
# same_meaning_with_targets               0.617329
# justified_with_targets                  0.606498
# mnli_crowdsource_with_targets           0.606498
# infer_with_targets                      0.599278
# gpt_3_yes_no_without_targets            0.595668
# follow_with_targets                     0.592058
# inflection_with_targets                 0.588448
# sentiment_with_targets                  0.584838
# imply_with_targets                      0.574007
# similar_words_with_targets              0.574007
# start_with_the_with_targets             0.570397
# gpt_3_yes_no_with_targets               0.566787
# null_pattern_with_targets               0.563177
# null_pattern_without_targets            0.541516
# paraphrase_r_with_targets               0.534296
# words_appear_with_targets               0.523466
# null_pattern_r_with_targets             0.505415
# null_pattern_r_without_targets          0.501805
# hypothesis_only_without_targets         0.501805
# gpt_3_cat_dog_with_targets_yes_no       0.487365
# premise_only_without_targets            0.480144
# gpt_3_cat_dog_with_targets              0.476534
# sentiment_cat_dog_with_targets          0.476534
# premise_only_with_targets               0.472924
# hypothesis_only_with_targets            0.472924
# bigscience-T0 (sorted by task score performance)
#                                         task em performance  \
# imply_with_targets                      0.851986
# based_on_previous_passage_with_targets  0.848375
# mnli_crowdsource_with_targets           0.841155
# should_assume_with_targets              0.837545
# must_be_true_with_targets               0.833935
# gpt_3_true_false_with_targets           0.823105
# infer_with_targets                      0.819495
# guaranteed_with_targets                 0.819495
# gpt_3_yes_no_with_targets               0.805054
# gpt_3_yes_no_without_targets            0.292419
# justified_with_targets                  0.776173
# paraphrase_with_targets                 0.776173
# summarize_with_targets                  0.761733
# follow_with_targets                     0.747292
# start_with_the_with_targets             0.743682
# similar_words_with_targets              0.740072
# same_meaning_with_targets               0.740072
# words_appear_with_targets               0.732852
# inflection_with_targets                 0.732852
# null_pattern_with_targets               0.693141
# sentiment_with_targets                  0.148014
# paraphrase_r_with_targets               0.624549
# null_pattern_r_with_targets             0.588448
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# null_pattern_without_targets            0.014440
# null_pattern_r_without_targets          0.007220
# premise_only_with_targets               0.483755
# hypothesis_only_with_targets            0.494585
# hypothesis_only_without_targets         0.000000
# premise_only_without_targets            0.000000
# gpt_3_cat_dog_with_targets              0.472924
# sentiment_cat_dog_with_targets          0.036101
#
#                                         task score performance
# imply_with_targets                      0.851986
# based_on_previous_passage_with_targets  0.848375
# mnli_crowdsource_with_targets           0.841155
# should_assume_with_targets              0.837545
# must_be_true_with_targets               0.833935
# gpt_3_true_false_with_targets           0.823105
# infer_with_targets                      0.819495
# guaranteed_with_targets                 0.819495
# gpt_3_yes_no_with_targets               0.805054
# gpt_3_yes_no_without_targets            0.801444
# justified_with_targets                  0.776173
# paraphrase_with_targets                 0.776173
# summarize_with_targets                  0.761733
# follow_with_targets                     0.747292
# start_with_the_with_targets             0.743682
# similar_words_with_targets              0.740072
# same_meaning_with_targets               0.740072
# words_appear_with_targets               0.732852
# inflection_with_targets                 0.732852
# null_pattern_with_targets               0.693141
# sentiment_with_targets                  0.667870
# paraphrase_r_with_targets               0.624549
# null_pattern_r_with_targets             0.602888
# gpt_3_cat_dog_with_targets_yes_no       0.588448
# null_pattern_without_targets            0.581227
# null_pattern_r_without_targets          0.541516
# premise_only_with_targets               0.494585
# hypothesis_only_with_targets            0.494585
# hypothesis_only_without_targets         0.480144
# premise_only_without_targets            0.476534
# gpt_3_cat_dog_with_targets              0.472924
# sentiment_cat_dog_with_targets          0.462094
# google-t5-xl-lm-adapt (sorted by task score performance)
#                                         task em performance  \
# gpt_3_yes_no_with_targets               0.000000
# gpt_3_yes_no_without_targets            0.000000
# should_assume_with_targets              0.000000
# null_pattern_with_targets               0.231047
# hypothesis_only_with_targets            0.173285
# null_pattern_r_with_targets             0.151625
# inflection_with_targets                 0.158845
# start_with_the_with_targets             0.050542
# follow_with_targets                     0.151625
# must_be_true_with_targets               0.191336
# paraphrase_with_targets                 0.108303
# sentiment_with_targets                  0.108303
# based_on_previous_passage_with_targets  0.000000
# infer_with_targets                      0.007220
# imply_with_targets                      0.018051
# justified_with_targets                  0.148014
# paraphrase_r_with_targets               0.043321
# summarize_with_targets                  0.101083
# same_meaning_with_targets               0.083032
# mnli_crowdsource_with_targets           0.000000
# similar_words_with_targets              0.000000
# words_appear_with_targets               0.000000
# guaranteed_with_targets                 0.003610
# sentiment_cat_dog_with_targets          0.079422
# premise_only_with_targets               0.148014
# gpt_3_cat_dog_with_targets              0.007220
# gpt_3_true_false_with_targets           0.000000
# hypothesis_only_without_targets         0.000000
# null_pattern_without_targets            0.000000
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# null_pattern_r_without_targets          0.000000
# premise_only_without_targets            0.000000
#
#                                         task score performance
# gpt_3_yes_no_with_targets               0.552347
# gpt_3_yes_no_without_targets            0.548736
# should_assume_with_targets              0.537906
# null_pattern_with_targets               0.537906
# hypothesis_only_with_targets            0.530686
# null_pattern_r_with_targets             0.530686
# inflection_with_targets                 0.530686
# start_with_the_with_targets             0.530686
# follow_with_targets                     0.530686
# must_be_true_with_targets               0.527076
# paraphrase_with_targets                 0.527076
# sentiment_with_targets                  0.527076
# based_on_previous_passage_with_targets  0.527076
# infer_with_targets                      0.527076
# imply_with_targets                      0.527076
# justified_with_targets                  0.527076
# paraphrase_r_with_targets               0.527076
# summarize_with_targets                  0.527076
# same_meaning_with_targets               0.527076
# mnli_crowdsource_with_targets           0.527076
# similar_words_with_targets              0.527076
# words_appear_with_targets               0.527076
# guaranteed_with_targets                 0.527076
# sentiment_cat_dog_with_targets          0.527076
# premise_only_with_targets               0.523466
# gpt_3_cat_dog_with_targets              0.523466
# gpt_3_true_false_with_targets           0.523466
# hypothesis_only_without_targets         0.483755
# null_pattern_without_targets            0.480144
# gpt_3_cat_dog_with_targets_yes_no       0.476534
# null_pattern_r_without_targets          0.465704
# premise_only_without_targets            0.462094
# google-t5-xxl-lm-adapt (sorted by task score performance)
#                                         task em performance  \
# gpt_3_yes_no_without_targets            0.000000
# gpt_3_yes_no_with_targets               0.003610
# gpt_3_cat_dog_with_targets_yes_no       0.000000
# summarize_with_targets                  0.003610
# imply_with_targets                      0.003610
# same_meaning_with_targets               0.003610
# null_pattern_with_targets               0.025271
# should_assume_with_targets              0.021661
# must_be_true_with_targets               0.003610
# justified_with_targets                  0.010830
# guaranteed_with_targets                 0.000000
# follow_with_targets                     0.010830
# hypothesis_only_with_targets            0.003610
# paraphrase_with_targets                 0.007220
# inflection_with_targets                 0.007220
# sentiment_with_targets                  0.007220
# paraphrase_r_with_targets               0.021661
# start_with_the_with_targets             0.028881
# similar_words_with_targets              0.000000
# words_appear_with_targets               0.144404
# infer_with_targets                      0.018051
# based_on_previous_passage_with_targets  0.010830
# mnli_crowdsource_with_targets           0.000000
# sentiment_cat_dog_with_targets          0.000000
# null_pattern_r_with_targets             0.043321
# premise_only_with_targets               0.025271
# gpt_3_cat_dog_with_targets              0.000000
# gpt_3_true_false_with_targets           0.000000
# null_pattern_without_targets            0.000000
# hypothesis_only_without_targets         0.000000
# null_pattern_r_without_targets          0.000000
# premise_only_without_targets            0.000000
#
#                                         task score performance
# gpt_3_yes_no_without_targets            0.592058
# gpt_3_yes_no_with_targets               0.581227
# gpt_3_cat_dog_with_targets_yes_no       0.552347
# summarize_with_targets                  0.534296
# imply_with_targets                      0.534296
# same_meaning_with_targets               0.530686
# null_pattern_with_targets               0.530686
# should_assume_with_targets              0.530686
# must_be_true_with_targets               0.530686
# justified_with_targets                  0.530686
# guaranteed_with_targets                 0.530686
# follow_with_targets                     0.530686
# hypothesis_only_with_targets            0.530686
# paraphrase_with_targets                 0.530686
# inflection_with_targets                 0.527076
# sentiment_with_targets                  0.527076
# paraphrase_r_with_targets               0.527076
# start_with_the_with_targets             0.527076
# similar_words_with_targets              0.527076
# words_appear_with_targets               0.527076
# infer_with_targets                      0.527076
# based_on_previous_passage_with_targets  0.527076
# mnli_crowdsource_with_targets           0.523466
# sentiment_cat_dog_with_targets          0.523466
# null_pattern_r_with_targets             0.519856
# premise_only_with_targets               0.519856
# gpt_3_cat_dog_with_targets              0.494585
# gpt_3_true_false_with_targets           0.490975
# null_pattern_without_targets            0.490975
# hypothesis_only_without_targets         0.480144
# null_pattern_r_without_targets          0.469314
# premise_only_without_targets            0.465704

# %%
# # check where score based prediction and em based prediction disagree
# prompt = "gpt_3_yes_no_with_targets"
# df_check = models_inputs["google-t5-xl-lm-adapt"]
# df_check[prompt][df_check[prompt]["prediction"] != df_check[prompt]["argmax score prediction"]].head(15)
